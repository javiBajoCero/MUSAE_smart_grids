# %%
import os
import numpy as np
import pandas as pd
import tempfile
import random
import pandapower as pp
import plotly.express as px
from pandapower.timeseries import DFData
from pandapower.timeseries import OutputWriter
from pandapower.timeseries.run_time_series import run_timeseries
from pandapower.control import ConstControl

# %%
net = pp.from_excel('exported_real_net_to_excel.xlsx') #to import the net from an excel file
print(net)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (14 element)
#    - load (4 element)
#    - gen (1 elements)
#    - ext_grid (1 elements)
#    - line (6 element)
#    - trafo (4 element)
#    - bus_geodata (14 element)

# %%
#creating datasource profiles
profiles = pd.DataFrame(index = [i for i in range(0, 24)], columns = ['demand_pu','Wind_pu','Solar_pu']) #hours and columns
profiles  = pd.read_excel('Database_only_interesting_columns.xlsx')

profiles
# Out:
#     demand_pu   Wind_pu  Solar_pu
# 0    0.771616  0.931438  0.005322
# 1    0.718749  0.943276  0.005279
# 2    0.676308  0.930074  0.004979
# 3    0.653702  0.895595  0.005033
# 4    0.643821  0.870152  0.005022
# 5    0.643821  0.870152  0.005022
# 6    0.646267  0.865410  0.004850
# 7    0.681455  0.858119  0.004872
# 8    0.767729  0.882027  0.004979
# 9    0.849291  0.898719  0.004689
# 10   0.887761  0.891390  0.061281
# 11   0.917473  0.883220  0.440301
# 12   0.922664  0.871464  0.778138
# 13   0.915181  0.854004  0.912751
# 14   0.915252  0.871069  0.962723
# 15   0.915709  0.893224  1.000000
# 16   0.891402  0.891085  0.966789
# 17   0.876307  0.901000  0.848562
# 18   0.876418  0.899054  0.419431
# 19   0.915753  0.910266  0.038554
# 20   0.953834  0.935560  0.006696
# 21   0.982918  0.962845  0.006288
# 22   0.993716  0.982041  0.005870
# 23   0.937120  0.996183  0.005730

# %%
profiles['loadtype1_real'] = profiles['demand_pu']*55;
profiles['loadtype2_real'] = profiles['demand_pu']*150;
profiles
# Out:
#     demand_pu   Wind_pu  Solar_pu  loadtype1_real  loadtype2_real
# 0    0.771616  0.931438  0.005322       42.438880      115.742400
# 1    0.718749  0.943276  0.005279       39.531199      107.812362
# 2    0.676308  0.930074  0.004979       37.196934      101.446185
# 3    0.653702  0.895595  0.005033       35.953628       98.055349
# 4    0.643821  0.870152  0.005022       35.410173       96.573199
# 5    0.643821  0.870152  0.005022       35.410173       96.573199
# 6    0.646267  0.865410  0.004850       35.544706       96.940108
# 7    0.681455  0.858119  0.004872       37.479998      102.218177
# 8    0.767729  0.882027  0.004979       42.225107      115.159383
# 9    0.849291  0.898719  0.004689       46.710982      127.393587
# 10   0.887761  0.891390  0.061281       48.826847      133.164128
# 11   0.917473  0.883220  0.440301       50.461029      137.620989
# 12   0.922664  0.871464  0.778138       50.746522      138.399606
# 13   0.915181  0.854004  0.912751       50.334940      137.277110
# 14   0.915252  0.871069  0.962723       50.338873      137.287836
# 15   0.915709  0.893224  1.000000       50.363975      137.356296
# 16   0.891402  0.891085  0.966789       49.027085      133.710233
# 17   0.876307  0.901000  0.848562       48.196865      131.445995
# 18   0.876418  0.899054  0.419431       48.202996      131.462716
# 19   0.915753  0.910266  0.038554       50.366405      137.362922
# 20   0.953834  0.935560  0.006696       52.460869      143.075098
# 21   0.982918  0.962845  0.006288       54.060464      147.437629
# 22   0.993716  0.982041  0.005870       54.654354      149.057330
# 23   0.937120  0.996183  0.005730       51.541577      140.567937
